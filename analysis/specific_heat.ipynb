# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
directory = "../data/35Test.xlsx"
df = pd.read_excel(directory)
specific_heat = pd.read_excel(directory)["Specific_Heat"]

# %%
plt.plot(df.Temperature, specific_heat)
